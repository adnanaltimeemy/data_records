# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("houses.csv")

print(df.head())
print(df.info())
# Out:
#           Name  Level Unlocked  Payout (Coins)  Payout (Elixir)  \
# 0      Cottage             NaN           200.0              NaN
# 1   Town House             NaN           250.0              NaN
# 2  Brick House             NaN           400.0              NaN
# 3  Royal Villa            12.0             NaN              NaN
# 4  Hobbit Home            15.0             NaN              NaN
#
#    Payout Time (Hours)  Cost (Coins)  Cost (Diamonds)
# 0                  8.0         500.0              NaN
# 1                 10.0         900.0              NaN
# 2                 12.0        1800.0              NaN
# 3                  NaN           NaN              NaN
# 4                  NaN           NaN              NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 8 non-null      str
# ...

# %%
# Drop duplicates
df = df.drop_duplicates()

# Fill missing values (basic approach)
df = df.fillna("")

# %%
text_features = df.select_dtypes(include=["string", "object"]).columns.tolist()

# optionally filter out object columns that are not actually strings
text_features = [
    col for col in text_features
    if df[col].dropna().map(type).eq(str).all()
]

# %%
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean")),
    ("scaler", StandardScaler())
])

# %%
numeric_transformer = Pipeline(steps=[
    ("scaler", StandardScaler())
])

text_transformer = Pipeline(steps=[
    ("tfidf", TfidfVectorizer(stop_words="english"))
])

# %%
df = df.copy()
df = df.fillna("missing")

# %%
df.head()
# Out:
#           Name Level Unlocked Payout (Coins) Payout (Elixir)  \
# 0      Cottage                         200.0
# 1   Town House                         250.0
# 2  Brick House                         400.0
# 3  Royal Villa           12.0
# 4  Hobbit Home           15.0
#
#   Payout Time (Hours) Cost (Coins) Cost (Diamonds)
# 0                 8.0        500.0
# 1                10.0        900.0
# 2                12.0       1800.0
# 3
# 4

# %%
df.columns
# Out:
# Index(['Name', 'Level Unlocked', 'Payout (Coins)', 'Payout (Elixir)',
#        'Payout Time (Hours)', 'Cost (Coins)', 'Cost (Diamonds)'],
#       dtype='str')

# %%
hasattr(model.named_steps["preprocessor"], "transformers_")
# Out:
# False

# %%
print(dir())
# Out:
# ['ColumnTransformer', 'In', 'KMeans', 'OneHotEncoder', 'Out', 'PCA', 'Pipeline', 'SimpleImputer', 'StandardScaler', 'TfidfVectorizer', '_', '_13', '_17', '_19', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'categorical_features', 'df', 'exit', 'get_ipython', 'k', 'model', 'np', 'numeric_features', 'numeric_transformer', 'open', 'pd', 'plt', 'preprocessor', 'quit', 'text_features', 'text_transformer']

# %%
X = pd.get_dummies(df_clean)
