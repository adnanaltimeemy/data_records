# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Merge1.csv")

# View first rows
df.head()
# Out:
#          date      a   b    c
# 0  2022-01-01   9000  35  140
# 1  2022-01-02   8000  12  920
# 2  2022-01-03  69000  42  370
# 3  2022-01-04  81000  29  900
# 4  2022-01-05  91000  35  770

# %%
df.info()
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    90 non-null     str
#  1   a       90 non-null     int64
#  2   b       90 non-null     int64
#  3   c       90 non-null     int64
# dtypes: int64(3), str(1)
# memory usage: 3.8 KB
# date    0
# a       0
# b       0
# c       0
# dtype: int64

# %%
# Fill missing values (simple approach)
df = df.fillna(df.median(numeric_only=True))

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['date', 'a', 'b', 'c'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['date', 'a', 'b', 'c'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['date', 'a', 'b', 'c'], dtype='str')

# %%
print("y_test exists:", "y_test" in globals())
print("rf_pred exists:", "rf_pred" in globals())
# Out:
# y_test exists: False
# rf_pred exists: False

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'RandomForestClassifier', 'ExtraTreesClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_2', '_i3', '_3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_i10', '_i11', 'rf_model', '_i12', '_i13', '_i14', '_i15', '_15', '_i16', '_i17', '_i18', '_i19', '_i20', '_i21', '_i22', '_i23', 'et_model', '_i24'])

# %%
print("X_test exists?", "X_test" in globals())
# Out:
# X_test exists? False

# %%
'y_test' in globals()
# Out:
# False
