# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv("lap-times-youtube.csv")

df.head()
# Out:
#                   Track  ...                                         Link
# 0  Dragon Trail Gardens  ...  https://www.youtube.com/watch?v=7gBBstmvVWs
# 1       Tsukuba Circuit  ...  https://www.youtube.com/watch?v=y6kpTLAK-KY
# 2           Deep Forest  ...  https://www.youtube.com/watch?v=ZC9rUq2R26I
#
# [3 rows x 6 columns]

# %%
print(df.info())
print(df.describe())

print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Track               3 non-null      str
#  1   Driver              3 non-null      str
#  2   Car                 3 non-null      str
#  3   Performance Points  1 non-null      float64
#  4   Lap Time            3 non-null      str
#  5   Link                3 non-null      str
# dtypes: float64(1), str(5)
# memory usage: 597.0 bytes
# None
#        Performance Points
# count                 1.0
# mean                600.0
# std                   NaN
# min                 600.0
# 25%                 600.0
# 50%                 600.0
# 75%                 600.0
# max                 600.0
# Track                 0
# Driver                0
# Car                   0
# Performance Points    2
# Lap Time              0
# Link                  0
# dtype: int64

# %%
df = df.fillna("")

# %%
text_column = "youtube_text"   # change if needed
numeric_column = "lap_time"     # change if needed

# %%
print(df.columns)
# Out:
# Index(['Track', 'Driver', 'Car', 'Performance Points', 'Lap Time', 'Link'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Track', 'Driver', 'Car', 'Performance Points', 'Lap Time', 'Link'], dtype='str')

# %%
for col in df.columns:
    print(col, df[col].astype(str).str.len().mean())
# Out:
# Track 15.333333333333334
# Driver 13.0
# Car 27.666666666666668
# Performance Points 1.6666666666666667
# Lap Time 8.0
# Link 43.0

# %%
for col in df.columns:
    print(col)
# Out:
# Track
# Driver
# Car
# Performance Points
# Lap Time
# Link

# %%
df.columns.tolist()
# Out:
# ['Track', 'Driver', 'Car', 'Performance Points', 'Lap Time', 'Link']

# %%
if numeric_column in df.columns:
    numeric_features = scaler.fit_transform(df[[numeric_column]])
else:
    print("Column not found:", numeric_column)
# Out:
# Column not found: lap_time

# %%
print('numeric_features' in globals())
print('text_features' in globals())
# Out:
# False
# False

# %%
from sklearn.decomposition import PCA

# Example data (replace with your own)
X = [[1, 2, 3],
     [4, 5, 6],
     [7, 8, 9]]

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

print(X_pca)
# Out:
# [[-5.19615242e+00  5.55006974e-17]
#  [ 0.00000000e+00 -0.00000000e+00]
#  [ 5.19615242e+00  5.55006974e-17]]

# %%
print(type(X))
print(len(X))
print(X[:2])
# Out:
# <class 'list'>
# 3
# [[1, 2, 3], [4, 5, 6]]

# %%
print(type(X[0]))
print(X[:3])
# Out:
# <class 'list'>
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
X = np.array(X)
print(X.shape)
print(df.shape)
print(len(df))
# Out:
# (3, 3)
# (3, 6)
# 3

# %%
print(type(kmeans))
print(kmeans)
# Out:
# <class 'sklearn.cluster._kmeans.KMeans'>
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %%
[col for col in df.columns if "clus" in col.lower()]
# Out:
# []

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#                   Track  ...                                         Link
# 0  Dragon Trail Gardens  ...  https://www.youtube.com/watch?v=7gBBstmvVWs
# 1       Tsukuba Circuit  ...  https://www.youtube.com/watch?v=y6kpTLAK-KY
# 2           Deep Forest  ...  https://www.youtube.com/watch?v=ZC9rUq2R26I
#
# [3 rows x 6 columns]
# ['Track', 'Driver', 'Car', 'Performance Points', 'Lap Time', 'Link']
