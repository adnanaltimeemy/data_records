# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("ships.csv")

df.head()
# Out:
#                      Name  ...                                        Description
# 0  Arcadia Class Jumpship  ...  Arcadians were the most common jumpships durin...
# 1  Arcadia Class Jumpship  ...  Serviced by the Tower shipyard, this jumpship ...
# 2        Kestrel Class AX  ...  Base model experimental jumpship. Ships capabl...
# 3        Kestrel Class CX  ...  Base model experimental jumpship. Ships capabl...
# 4       Kestrel Class CX0  ...  Base model experimental jumpship. The Kestrel ...
#
# [5 rows x 3 columns]

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (18, 3)
# <class 'pandas.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         18 non-null     str
#  1   Rarity       18 non-null     str
#  2   Description  18 non-null     str
# dtypes: str(3)
# memory usage: 3.7 KB
# None
#                           Name  ...                                        Description
# count                       18  ...                                                 18
# unique                      17  ...                                                 13
# top     Arcadia Class Jumpship  ...  Base model experimental jumpship. Ships capabl...
# freq                         2  ...                                                  3
#
# [4 rows x 3 columns]

# %%
df = df.dropna()  # simple option (you can also impute instead)

# %%
label_encoders = {}

for col in df.select_dtypes(include=["object", "string"]).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
[c for c in df.columns if "target" in c.lower()]
# Out:
# []

# %%
df.head()
# Out:
#    Name  Rarity  Description
# 0     0       0            0
# 1     0       0            7
# 2     1       0            2
# 3     2       0            2
# 4     3       0            3

# %%
print(df.columns)
# Out:
# Index(['Name', 'Rarity', 'Description'], dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#    Name  Rarity  Description
# 0     0       0            0
# 1     0       0            7
# 2     1       0            2
# 3     2       0            2
# 4     3       0            3
# Index(['Name', 'Rarity', 'Description'], dtype='str')

# %%
print(df.columns)
df.head()
# Out:
# Index(['Name', 'Rarity', 'Description'], dtype='str')
#    Name  Rarity  Description
# 0     0       0            0
# 1     0       0            7
# 2     1       0            2
# 3     2       0            2
# 4     3       0            3

# %%
df.head()
df.columns
# Out:
# Index(['Name', 'Rarity', 'Description'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Name', 'Rarity', 'Description'], dtype='str')

# %%
print(rf)
print(hasattr(rf, "estimators_"))
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)
# False
