# %%
import pandas as pd
import numpy as np

# NLP
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# ML
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("gala-mode.csv")

df.head()
# Out:
#            Mode   Record
# 0  Steeplechase  1'21"50
# 1       Bastion      708
# 2      Marksman      459
# 3  Calligrapher  2'01"63

# %%
print(df.columns)
print(df.info())
# Out:
# Index(['Mode', 'Record'], dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mode    4 non-null      str
#  1   Record  4 non-null      str
# dtypes: str(2)
# memory usage: 255.0 bytes
# None

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Mode', 'Record'], dtype='str')

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#            Mode   Record
# 0  Steeplechase  1'21"50
# 1       Bastion      708
# 2      Marksman      459
# 3  Calligrapher  2'01"63
# ['Mode', 'Record']

# %%
print(df.columns)
# Out:
# Index(['Mode', 'Record'], dtype='str')

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

texts = [
    "apple banana fruit",
    "dog cat animal",
    "car bus train transport",
    "orange apple banana",
    "cat dog pet",
    "train station railway",
]

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(texts)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans.fit(X)

terms = vectorizer.get_feature_names_out()

def get_top_terms(center):
    return [terms[i] for i in center.argsort()[-10:]]

for i, center in enumerate(kmeans.cluster_centers_):
    print(f"\nCluster {i}")
    print(get_top_terms(center))
# Out:
# Cluster 0
# ['dog', 'fruit', 'orange', 'pet', 'bus', 'car', 'railway', 'station', 'transport', 'train']
#
# Cluster 1
# ['fruit', 'orange', 'railway', 'station', 'train', 'transport', 'animal', 'pet', 'cat', 'dog']
#
# Cluster 2
# ['dog', 'pet', 'railway', 'station', 'train', 'transport', 'fruit', 'orange', 'apple', 'banana']

# %%
print(df.head())
# Out:
#            Mode   Record
# 0  Steeplechase  1'21"50
# 1       Bastion      708
# 2      Marksman      459
# 3  Calligrapher  2'01"63

# %%
df.to_csv("gala_mode_clustered.csv", index=False)
