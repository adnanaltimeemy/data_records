# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("tracks.csv")

# View basic info
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   Country                    Track  ... Length (miles) Length (km)
# 0  Canada            Cayoosh Point  ...            4.7         7.5
# 1  Canada  Cayoosh Point (Reverse)  ...            4.7         7.5
# 2  Canada            Fraser Valley  ...            1.6         2.6
# 3  Canada  Fraser Valley (Reverse)  ...            1.6         2.6
# 4  Canada                   Lytton  ...            5.2         8.4
#
# [5 rows x 7 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         114 non-null    str
#  1   Track           114 non-null    str
#  2   Direction       114 non-null    str
#  3   Type            114 non-null    str
#  4   DLC             114 non-null    str
#  5   Length (miles)  114 non-null    float64
#  6   Length (km)     114 non-null    float64
# dtypes: float64(2), str(5)
# memory usage: 12.1 KB
# None
#        Length (miles)  Length (km)
# count      114.000000   114.000000
# mean         2.594912     4.175439
# std          1.624892     2.611125
# min          0.600000     1.000000
# 25%          1.360000     2.200000
# 50%          2.100000     3.400000
# 75%          3.200000     5.150000
# max          6.300000    10.200000

# %%
from sklearn.preprocessing import LabelEncoder

df = df.copy()

# handle missing values (safer option)
df = df.fillna("Unknown")

label_encoders = {}

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
if target_column in df.columns:
    X = df.drop(columns=[target_column])
    y = df[target_column]
else:
    print("Column not found:", target_column)
# Out:
# Column not found: target_column

# %%
df.columns
# Out:
# Index(['Country', 'Track', 'Direction', 'Type', 'DLC', 'Length (miles)',
#        'Length (km)'],
#       dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#    Country  Track  Direction  Type  DLC  Length (miles)  Length (km)
# 0        0     25          0     0    0             4.7          7.5
# 1        0     26          1     0    0             4.7          7.5
# 2        0     29          0     2    0             1.6          2.6
# 3        0     30          1     2    0             1.6          2.6
# 4        0     61          0     0    0             5.2          8.4
# Index(['Country', 'Track', 'Direction', 'Type', 'DLC', 'Length (miles)',
#        'Length (km)'],
#       dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Country', 'Track', 'Direction', 'Type', 'DLC', 'Length (miles)',
#        'Length (km)'],
#       dtype='str')

# %%
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)
