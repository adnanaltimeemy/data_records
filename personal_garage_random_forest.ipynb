# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("personal-garage.csv")

df.head()
# Out:
#     Manufacturer                   Model
# 0          Honda         Honda Sport VGT
# 1        Hyundai  Genesis Gr.B Rally Car
# 2  Renault Sport  Megane R.S. Trophy '11

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Manufacturer  3 non-null      str
#  1   Model         3 non-null      str
# dtypes: str(2)
# memory usage: 264.0 bytes
# None
#        Manufacturer            Model
# count             3                3
# unique            3                3
# top           Honda  Honda Sport VGT
# freq              1                1
# Manufacturer    0
# Model           0
# dtype: int64

# %%
df = df.dropna()   # or you can use fillna if needed

# %%
label_encoders = {}

for col in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
print(df.columns)
print(df.head())
print("target" in df.columns)
# Out:
# Index(['Manufacturer', 'Model'], dtype='str')
#    Manufacturer  Model
# 0             0      1
# 1             1      0
# 2             2      2
# False

# %%
print(df.columns)
# Out:
# Index(['Manufacturer', 'Model'], dtype='str')

# %%
print(df.head())
print(df.columns)
# Out:
#    Manufacturer  Model
# 0             0      1
# 1             1      0
# 2             2      2
# Index(['Manufacturer', 'Model'], dtype='str')

# %%
df.head()
df.columns
# Out:
# Index(['Manufacturer', 'Model'], dtype='str')

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'accuracy_score', 'classification_report', 'DecisionTreeClassifier', 'RandomForestClassifier', '_i2', 'df', '_2', '_i3', '_i4', '_i5', '_i6', 'label_encoders', 'col', 'le', '_i7', '_i8', '_i9', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', 'tree_model', '_i16', '_i17', '_i18', '_i19', '_i20', '_i21', '_21', '_i22', 'rf_model', '_i23', '_23', '_i24', '_i25'])

# %%
print(dir())
# Out:
# ['DecisionTreeClassifier', 'In', 'LabelEncoder', 'Out', 'RandomForestClassifier', '_', '_2', '_21', '_23', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'classification_report', 'col', 'df', 'exit', 'get_ipython', 'label_encoders', 'le', 'np', 'open', 'pd', 'quit', 'rf_model', 'train_test_split', 'tree_model']

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model'], dtype='str')
