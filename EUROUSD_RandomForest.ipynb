# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EUROUSD.csv")
df.head()
# Out:
#               Date\tPrice\tOpen\tHigh\tLow\tChange %
# 0  Mar 01, 2019\t1.1377\t1.1372\t1.141\t1.1353\t0...
# 1  Feb 28, 2019\t1.1371\t1.1371\t1.1421\t1.1357\t...
# 2  Feb 27, 2019\t1.1369\t1.1396\t1.1404\t1.136\t-...
# 3  Feb 26, 2019\t1.1387\t1.1366\t1.1404\t1.1343\t...
# 4  Feb 25, 2019\t1.1359\t1.1338\t1.1369\t1.1323\t...

# %%
# Check missing values
print(df.isnull().sum())

# Drop missing rows (simple approach)
df = df.dropna()
# Out:
# Date\tPrice\tOpen\tHigh\tLow\tChange %    0
# dtype: int64

# %%
if "Date" in df.columns:
    df["Date"] = pd.to_datetime(df["Date"])
    df = df.sort_values("Date")

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'Date	Price	Open	High	Low	Change %'

# %%
print(df.head())
print(df.columns)
print(type(df.columns))
# Out:
#               date\tprice\topen\thigh\tlow\tchange %
# 0  Mar 01, 2019\t1.1377\t1.1372\t1.141\t1.1353\t0...
# 1  Feb 28, 2019\t1.1371\t1.1371\t1.1421\t1.1357\t...
# 2  Feb 27, 2019\t1.1369\t1.1396\t1.1404\t1.136\t-...
# 3  Feb 26, 2019\t1.1387\t1.1366\t1.1404\t1.1343\t...
# 4  Feb 25, 2019\t1.1359\t1.1338\t1.1369\t1.1323\t...
# Index(['date\tprice\topen\thigh\tlow\tchange %'], dtype='str')
# <class 'pandas.Index'>

# %%
print(df.head())
# Out:
#               date\tprice\topen\thigh\tlow\tchange %
# 0  Mar 01, 2019\t1.1377\t1.1372\t1.141\t1.1353\t0...
# 1  Feb 28, 2019\t1.1371\t1.1371\t1.1421\t1.1357\t...
# 2  Feb 27, 2019\t1.1369\t1.1396\t1.1404\t1.136\t-...
# 3  Feb 26, 2019\t1.1387\t1.1366\t1.1404\t1.1343\t...
# 4  Feb 25, 2019\t1.1359\t1.1338\t1.1369\t1.1323\t...

# %%
print(df.columns)
# Out:
# Index(['date\tprice\topen\thigh\tlow\tchange %'], dtype='str')

# %%
print("y_test" in globals())
# Out:
# False

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'DecisionTreeRegressor', 'RandomForestRegressor', 'mean_squared_error', 'r2_score', 'plt', '_i2', 'df', '_2', '_i3', '_i4', '_i5', '_i6', 'col', '_i7', 'features', '_i8', '_i9', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', 'tree_model', '_i16', '_i17', '_i18', 'evaluate', '_i19', '_i20', '_i21', '_i22', '_i23', '_i24'])
