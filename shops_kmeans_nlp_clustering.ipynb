# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("shops.csv")

# Show first rows
df.head()
# Out:
#             Shop                         Item  Cost
# 0  Papa B's Pawn             Electronic Parts  50.0
# 1  Papa B's Pawn           Chemical Component   NaN
# 2  Papa B's Pawn  Unstable Chemical Component   NaN

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Shop    3 non-null      str
#  1   Item    3 non-null      str
#  2   Cost    1 non-null      float64
# dtypes: float64(1), str(2)
# memory usage: 304.0 bytes
# Shop    0
# Item    0
# Cost    2
# dtype: int64

# %%
df.columns = df.columns.str.lower()

# %%
if text_column in df.columns:
    df[text_column] = df[text_column].fillna("")
    texts = df[text_column]
else:
    print(f"Column '{text_column}' not found. Available columns: {df.columns}")
# Out:
# Column 'description' not found. Available columns: Index(['shop', 'item', 'cost'], dtype='str')

# %%
print(df.columns)
# Out:
# Index(['shop', 'item', 'cost'], dtype='str')

# %%
df.head()
# Out:
#             shop                         item  cost
# 0  Papa B's Pawn             Electronic Parts  50.0
# 1  Papa B's Pawn           Chemical Component   NaN
# 2  Papa B's Pawn  Unstable Chemical Component   NaN

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['shop', 'item', 'cost'], dtype='str')
#             shop                         item  cost
# 0  Papa B's Pawn             Electronic Parts  50.0
# 1  Papa B's Pawn           Chemical Component   NaN
# 2  Papa B's Pawn  Unstable Chemical Component   NaN

# %%
print("Columns:", df.columns)

if "cluster" not in df.columns:
    print("Cluster column missing!")
# Out:
# Columns: Index(['shop', 'item', 'cost'], dtype='str')
# Cluster column missing!
