# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("PandasExample.csv")
df.head()
# Out:
#            Name  Age  Gender
# 0        Nithin   24    Male
# 1         Manoj   30    Male
# 2  Shivashankar   44    Male
# 3        Swathi   18  Female
# 4   Pareekshith   28    Male

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (5, 3)
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   Gender  5 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 314.0 bytes
# None
#              Age
# count   5.000000
# mean   28.800000
# std     9.654015
# min    18.000000
# 25%    24.000000
# 50%    28.000000
# 75%    30.000000
# max    44.000000

# %%
print(df.isnull().sum())
# Out:
# Name      0
# Age       0
# Gender    0
# dtype: int64

# %%
for column in df.select_dtypes(include=['object', 'string']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

# %%
df.columns = df.columns.str.strip()

target_col = "target"

if target_col in df.columns:
    X = df.drop(target_col, axis=1)
    y = df[target_col]
else:
    print("Target column not found. Available columns:", df.columns)
# Out:
# Target column not found. Available columns: Index(['Name', 'Age', 'Gender'], dtype='str')

# %%
print("X_train exists:", "X_train" in globals())
print("y_train exists:", "y_train" in globals())
# Out:
# X_train exists: False
# y_train exists: False

# %%
print(df.head())
# Out:
#    Name  Age  Gender
# 0     1   24       1
# 1     0   30       1
# 2     3   44       1
# 3     4   18       0
# 4     2   28       1

# %%
print("y_test" in globals())
# Out:
# False

# %%
print(locals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'train_test_split', 'LabelEncoder', 'RandomForestClassifier', 'ExtraTreesClassifier', 'accuracy_score', 'classification_report', 'confusion_matrix', '_i2', 'df', '_2', '_i3', '_i4', '_i5', 'label_encoders', 'column', 'le', '_i6', '_i7', '_i8', 'target_col', '_i9', 'rf_model', '_i10', '_i11', 'et_model', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19'])

# %%
print(rf_model)
# Out:
# RandomForestClassifier(random_state=42)
