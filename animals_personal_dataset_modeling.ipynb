# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("animals-personal.csv")

print(df.head())
print(df.info())
# Out:
#                          Name Total Progress  ...  Tracked  Studied
# 0          American Alligator           100%  ...      4.0      Yes
# 1  American Alligator (small)           100%  ...      1.0      Yes
# 2                         NaN            NaN  ...      NaN      NaN
# 3             American Badger           100%  ...      3.0      Yes
# 4                         NaN            NaN  ...      NaN      NaN
#
# [5 rows x 6 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    str
#  1   Total Progress     100 non-null    str
#  2   Killed             80 non-null     float64
#  3   Skinned/Collected  80 non-null     float64
#  4   Tracked            44 non-null     float64
#  5   Studied            98 non-null     str
# dtypes: float64(3), str(3)
# memory usage: 10.5 KB
# None

# %%
print(df.columns.tolist())
# Out:
# ['Name', 'Total Progress', 'Killed', 'Skinned/Collected', 'Tracked', 'Studied']

# %%
y = ["cat", "dog", "cat", "bird"]

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Total Progress', 'Killed', 'Skinned/Collected', 'Tracked',
#        'Studied'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['Name', 'Total Progress', 'Killed', 'Skinned/Collected', 'Tracked',
#        'Studied'],
#       dtype='str')

# %%
import pandas as pd

print(df.head())
# Out:
#                          Name Total Progress  ...  Tracked  Studied
# 0          American Alligator           100%  ...      4.0      Yes
# 1  American Alligator (small)           100%  ...      1.0      Yes
# 2                         NaN            NaN  ...      NaN      NaN
# 3             American Badger           100%  ...      3.0      Yes
# 4                         NaN            NaN  ...      NaN      NaN
#
# [5 rows x 6 columns]

# %%
df.head()
df.columns
# Out:
# Index(['Name', 'Total Progress', 'Killed', 'Skinned/Collected', 'Tracked',
#        'Studied'],
#       dtype='str')

# %%
print(dir())
# Out:
# ['ColumnTransformer', 'ExtraTreesClassifier', 'In', 'LabelEncoder', 'OneHotEncoder', 'Out', 'Pipeline', 'RandomForestClassifier', 'StandardScaler', '_', '_22', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__session__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'accuracy_score', 'classification_report', 'confusion_matrix', 'df', 'exit', 'get_ipython', 'label_encoder', 'np', 'open', 'pd', 'quit', 'target_column', 'train_test_split', 'y']
